# %% [markdown]
# **Task 4**
#
# a. Use the dataset called [narcos.json](https://drive.google.com/file/d/1JdRVciBHaPu33Gc461nk6Y28EBD8dfyL/view?usp=sharing). In this json file is there a key named `WebChannel`?
#
# 1. Yes
# 2. **No**
#
# ```python
# your code goes here
# ```

# %%
import json
path = r"C:\Users\shaik.gousia\Desktop\Shaik_Kandukuru_Gousia\Cs_Files\narcos.json"
with open(path,"r",encoding="utf-8") as con:
    data = con.read()
dict_data = json.loads(data)
if "WebChannel" in dict_data:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# b. Now define a function called `fetch()` which takes the dictionary created after reading the json file and returns a list of lists with following fields:
#
# 1. id of the episode
# 2. url of the episode
# 3. name of the episode
# 4. season of the episode
# 5. number of the episode
# 6. type
# 7. airdate
# 8. airtime
# 9. airtimestamp
# 10. runtime
# 11. summary (Remove the ```<p>``` and ```</p>``` tags from the summary)

# %%
def fetch(dicttionary_json_data):
    result=[]
    for i in dicttionary_json_data['_embedded']['episodes']:
        result.append([i['id'], i['url'], i['name'], i['season'],i['number'],i['type'],i['airdate'],i['airtime'],i['airstamp'],
                            i['runtime'],
                            i['summary'].replace("<p>","").replace("</p>","")])

    return result ##result should be a list of lists with the fields given above.

# %%
fetch(dict_data)
# Out:
# [[203469,
#   'https://www.tvmaze.com/episodes/203469/narcos-1x01-descenso',
#   'Descenso',
#   1,
#   1,
#   'regular',
#   '2015-08-28',
#   '',
#   '2015-08-28T12:00:00+00:00',
#   57,
#   'A Chilean drugsproducer, the chemist Cockroach, brings his product to the Colombian smuggler Pablo Escobar. DEA-Agent Steve Murphy is fighting drugs in Bogota.'],
#  [208978,
#   'https://www.tvmaze.com/episodes/208978/narcos-1x02-the-sword-of-simon-bolivar',
#   'The Sword of Simón Bolívar',
#   1,
#   2,
#   'regular',
#   '2015-08-28',
#   '',
#   '2015-08-28T12:00:00+00:00',
#   47,
#   "The communistic radical group M-19 are counteracting the drug lords and Murphy's new partner Peña teaches him the Colombian way of law enforcement."],
#  [208979,
#   'https://www.tvmaze.com/episodes/208979/narcos-1x03-the-men-of-always',
#   'The Men of Always',
#   1,
#   3,
#   'regular',
#   '2015-08-28',
#   '',
#   '2015-08-28T12:00:00+00:00',
#   47,
#   "Murphy is confronted with corruption in the Colombian government once he tries to discolate Escobar's his political ambition together with his partner Peña."],
#  [208980,
#   'https://www.tvmaze.com/episodes/208980/narcos-1x04-the-palace-in-flames',
#   'The Palace in Flames',
#   1,
#   4,
#   'regular',
#   '2015-08-28',
#   '',
#   '2015-08-28T12:00:00+00:00',
#   44,
#   'Despite a new extradition treaty, the USA is increasing their budget to fight communism. It will create new challenges for Murphy and Peña to hunt for Pablo Escobar.'],
#  [208981,
#   'https://www.tvmaze.com/episodes/208981/narcos-1x05-there-will-be-a-future',
#   'There Will Be a Future',
#   1,
#   5,
#   'regular',
#   '2015-08-28',
#   '',
#   '2015-08-28T12:00:00+00:00',
#   55,
#   "Pablo's extreme methods is almost leading to a war between drug lords, Carillo and the government. Peña tries to protect his witness Elisa."],
#  [208982,
#   'https://www.tvmaze.com/episodes/208982/narcos-1x06-explosivos',
#   'Explosivos',
#   1,
#   6,
#   'regular',
#   '2015-08-28',
#   '',
#   '2015-08-28T12:00:00+00:00',
#   50,
#   'Gacha was almost caught by Peña and Carillo. Murphy tries to protect candidate Gaviria against assassins with ties to Pablo as she is in favour for extradition.'],
#  [208983,
#   'https://www.tvmaze.com/episodes/208983/narcos-1x07-you-will-cry-tears-of-blood',
#   'You Will Cry Tears of Blood',
#   1,
#   7,
#   'regular',
#   '2015-08-28',
#   '',
#   '2015-08-28T12:00:00+00:00',
#   51,
#   'Pablo went to hiding as political tides are turning against him, but he finds a way to beat back. The CIA is finally offering their help to Peña and Murphy.'],
#  [208984,
#   'https://www.tvmaze.com/episodes/208984/narcos-1x08-la-gran-mentira',
#   'La Gran Mentira',
#   1,
#   8,
#   'regular',
#   '2015-08-28',
#   '',
#   '2015-08-28T12:00:00+00:00',
#   51,
#   'A tragic mistake forces the government to change strategies to fight Pablo, but Pablo has bigger issues as there is danger from within his empire.'],
#  [208985,
#   'https://www.tvmaze.com/episodes/208985/narcos-1x09-la-catedral',
#   'La Catedral',
#   1,
#   9,
#   'regular',
#   '2015-08-28',
#   '',
#   '2015-08-28T12:00:00+00:00',
#   51,
#   'The hunt for Pablo seems to be over once he signs a deal with the government, but Murphy, Peña and the Calicartel have different thoughts about that.'],
#  [208986,
#   'https://www.tvmaze.com/episodes/208986/narcos-1x10-despegue',
#   'Despegue',
#   1,
#   10,
#   'regular',
#   '2015-08-28',
#   '',
#   '2015-08-28T12:00:00+00:00',
#   45,
#   "Pablo's activities in prison forces the government to use extreme actions. Murphy and Peña have to deal with a problematic situation."],
#  [832098,
#   'https://www.tvmaze.com/episodes/832098/narcos-2x01-free-at-last',
#   'Free at Last',
#   2,
#   1,
#   'regular',
#   '2016-09-02',
#   '',
#   '2016-09-02T12:00:00+00:00',
#   53,
#   'In the aftermath of a massive military effort to take Pablo into custody, the family reunites while enemies worry. Steve and Connie fight about safety.'],
#  [832099,
#   'https://www.tvmaze.com/episodes/832099/narcos-2x02-cambalache',
#   'Cambalache',
#   2,
#   2,
#   'regular',
#   '2016-09-02',
#   '',
#   '2016-09-02T12:00:00+00:00',
#   47,
#   "Tata gets impatient with life on the run. Pablo responds to President Gaviria's reward offer. Steve and Javier meet their new boss."],
#  [832100,
#   'https://www.tvmaze.com/episodes/832100/narcos-2x03-our-man-in-madrid',
#   'Our Man in Madrid',
#   2,
#   3,
#   'regular',
#   '2016-09-02',
#   '',
#   '2016-09-02T12:00:00+00:00',
#   47,
#   "President Gaviria has a new job for an old colleague. The Search Bloc's new tactics shake up Pablo, but also unsettle Steve and Javier."],
#  [832101,
#   'https://www.tvmaze.com/episodes/832101/narcos-2x04-the-good-the-bad-and-the-dead',
#   'The Good, the Bad, and the Dead',
#   2,
#   4,
#   'regular',
#   '2016-09-02',
#   '',
#   '2016-09-02T12:00:00+00:00',
#   56,
#   "The Cali cartel discusses moving in on Pablo's territory. Limon proposes a plan to Maritza. Tata gets a gun for protection."],
#  [832102,
#   'https://www.tvmaze.com/episodes/832102/narcos-2x05-the-enemies-of-my-enemy',
#   'The Enemies of My Enemy',
#   2,
#   5,
#   'regular',
#   '2016-09-02',
#   '',
#   '2016-09-02T12:00:00+00:00',
#   52,
#   'The Search Bloc gets a new leader. Javier loses faith in the system. Pablo brings Tata brother Carlos down from Miami to cheer her up.'],
#  [832103,
#   'https://www.tvmaze.com/episodes/832103/narcos-2x06-los-pepes',
#   'Los Pepes',
#   2,
#   6,
#   'regular',
#   '2016-09-02',
#   '',
#   '2016-09-02T12:00:00+00:00',
#   54,
#   "The newly-formed Los Pepes want to destroy Pablo and his empire. Tata's brother urges her to leave and seek safety with her children."],
#  [832256,
#   'https://www.tvmaze.com/episodes/832256/narcos-2x07-deutschland-93',
#   'Deutschland 93',
#   2,
#   7,
#   'regular',
#   '2016-09-02',
#   '',
#   '2016-09-02T12:00:00+00:00',
#   57,
#   'As the danger intensifies for the Escobars, Pablo sends his family to another country. Gaviria weighs the opportunity to use them as leverage.'],
#  [832257,
#   'https://www.tvmaze.com/episodes/832257/narcos-2x08-exit-el-patron',
#   'Exit El Patrón',
#   2,
#   8,
#   'regular',
#   '2016-09-02',
#   '',
#   '2016-09-02T12:00:00+00:00',
#   55,
#   'Colombia begins to turn on Escobar after his latest terrorist attack. Tata receives help from an unlikely ally. Quica gets increasingly anxious.'],
#  [832258,
#   'https://www.tvmaze.com/episodes/832258/narcos-2x09-nuestra-finca',
#   'Nuestra Finca',
#   2,
#   9,
#   'regular',
#   '2016-09-02',
#   '',
#   '2016-09-02T12:00:00+00:00',
#   57,
#   "Pablo is reunited with an estranged family member. Judy Moncada's life is put in danger. The DEA and CIA clash over how to handle Los Pepes."],
#  [832259,
#   'https://www.tvmaze.com/episodes/832259/narcos-2x10-al-fin-cayo',
#   'Al Fin Cayó!',
#   2,
#   10,
#   'regular',
#   '2016-09-02',
#   '',
#   '2016-09-02T12:00:00+00:00',
#   53,
#   "Javier deals with the repercussions from Judy's interview. Tata tries to convince Pablo to surrender for the sake of his children."],
#  [1249969,
#   'https://www.tvmaze.com/episodes/1249969/narcos-3x01-the-kingpin-strategy',
#   'The Kingpin Strategy',
#   3,
#   1,
#   'regular',
#   '2017-09-01',
#   '',
#   '2017-09-01T12:00:00+00:00',
#   55,
#   'The Gentlemen of Cali gather their associates together for a big surprise announcement about the future of their business.'],
#  [1285381,
#   'https://www.tvmaze.com/episodes/1285381/narcos-3x02-the-cali-kgb',
#   'The Cali KGB',
#   3,
#   2,
#   'regular',
#   '2017-09-01',
#   '',
#   '2017-09-01T12:00:00+00:00',
#   49,
#   'A gas incident threatens to disrupt the Cali-government deal and Jorge is asked to help out. Peña grapples with his former Los Pepes connection.'],
#  [1285382,
#   'https://www.tvmaze.com/episodes/1285382/narcos-3x03-follow-the-money',
#   'Follow the Money',
#   3,
#   3,
#   'regular',
#   '2017-09-01',
#   '',
#   '2017-09-01T12:00:00+00:00',
#   59,
#   "The Rodriguez brothers go into hiding during negotiations. Pacho meets with the Lord of the Skies in Mexico. Peña's new DEA team visits Cali."],
#  [1285383,
#   'https://www.tvmaze.com/episodes/1285383/narcos-3x04-checkmate',
#   'Checkmate',
#   3,
#   4,
#   'regular',
#   '2017-09-01',
#   '',
#   '2017-09-01T12:00:00+00:00',
#   53,
#   'Peña hatches a plan to try to capture Cali leader Gilberto Rodriguez. Amado proposes a business idea to Pacho.'],
#  [1285384,
#   'https://www.tvmaze.com/episodes/1285384/narcos-3x05-mro',
#   'MRO',
#   3,
#   5,
#   'regular',
#   '2017-09-01',
#   '',
#   '2017-09-01T12:00:00+00:00',
#   61,
#   'Paranoid about leaks, Miguel cracks down on his security. Pacho makes a decision about his new offer. Peña works on cultivating a witness.'],
#  [1285385,
#   'https://www.tvmaze.com/episodes/1285385/narcos-3x06-best-laid-plans',
#   'Best Laid Plans',
#   3,
#   6,
#   'regular',
#   '2017-09-01',
#   '',
#   '2017-09-01T12:00:00+00:00',
#   57,
#   'Jorge takes a dangerous risk. An accident in New York threatens to expose Chepe. Peña travels to Curaçao to arrest a potential witness.'],
#  [1285391,
#   'https://www.tvmaze.com/episodes/1285391/narcos-3x07-sin-salida',
#   'Sin Salida',
#   3,
#   7,
#   'regular',
#   '2017-09-01',
#   '',
#   '2017-09-01T12:00:00+00:00',
#   50,
#   'Peña plans another covert operation to take down a key Cali cartel member, but he risks running out of time during his search.'],
#  [1285392,
#   'https://www.tvmaze.com/episodes/1285392/narcos-3x08-convivir',
#   'Convivir',
#   3,
#   8,
#   'regular',
#   '2017-09-01',
#   '',
#   '2017-09-01T12:00:00+00:00',
#   51,
#   'David seeks revenge on behalf of his father, putting Enrique in danger. Peña asks Don Berna for help on a rescue mission.'],
#  [1285393,
#   'https://www.tvmaze.com/episodes/1285393/narcos-3x09-todos-los-hombres-del-presidente',
#   'Todos Los Hombres del Presidente',
#   3,
#   9,
#   'regular',
#   '2017-09-01',
#   '',
#   '2017-09-01T12:00:00+00:00',
#   47,
#   'David follows his suspicions. Peña is shocked to discover the depth of corruption in the Colombian government. Miguel is sought after once again.'],
#  [1285394,
#   'https://www.tvmaze.com/episodes/1285394/narcos-3x10-going-back-to-cali',
#   'Going Back to Cali',
#   3,
#   10,
#   'regular',
#   '2017-09-01',
#   '',
#   '2017-09-01T12:00:00+00:00',
#   51,
#   'David and Peña are in a race against each other to find Pallomari. Peña makes a serious decision about the future of his career.']]

# %% [markdown]
# c. Now write a function named `dump()` which will write the contents of the results obtained from `fetch()` defined earlier to a csv file. The headers of the file should be in the following order:
#
# 1. id
# 2. url
# 3. name
# 4. season
# 5. number
# 6. type
# 7. airdate
# 8. airtime
# 9. airtimestamp
# 10. runtime
# 11. summary
#
# The function should take the following inputs:
# 1. Path where you want to save the results
# 2. The name you want to give this file
# 3. The output of `fetch()` function
#
# The function should return:
# 1. True if file has been created
# 2. False otherwise (Hint use the `os` module in python to check if a file at a given location exits or not)

# %%
import os
import csv
def dump(path, name, results):
    h = ['id','url','name','season','number','type','airdate','airtime','airstamp','runtime','summary']
    p = path+"/"+name
    with open(p,'w',encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(h)
        for result in results:
            writer.writerow(result)
    if os.path.isfile(p):
        return True
    else:
        return False

# %%
path = r"C:\Users\shaik.gousia\Desktop\Shaik_Kandukuru_Gousia"
name = "task4"
dump(path,name,fetch(dict_data))
# Out:
# True
